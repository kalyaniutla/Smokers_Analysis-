# %%
import pandas as pd

# %%
file_path =C:\\Users\\Lenovo\\Downloads\\data-tobacco-use-prevalence-in-adults.csv
# Out:
#   File "C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15504\1901483859.py", line 1
#     file_path =C:\\Users\\Lenovo\\Downloads\\data-tobacco-use-prevalence-in-adults.csv
#                 ^
# SyntaxError: invalid syntax

# %%
data = pd.read_csv('C:\\Users\\Lenovo\\Downloads\\data-tobacco-use-prevalence-in-adults.csv')

# %%
data.head()
# Out:
#    YEAR                          DEMOGRAPHIC PERCENT    SE LOWER95 UPPER95
# 0  2016                                 Male    22.7   1.1    20.5    24.9
# 1  2016                               Female    10.5   0.9     8.8    12.1
# 2  2016  Non-Hispanic African American/Black    16.8   2.5      12    21.6
# 3  2016         Non-Hispanic American Indian    45.7  15.9    14.6    76.9
# 4  2016  Non-Hispanic Asian/Pacific Islander     8.5   1.3     5.9    11.1

# %%
data .describe()
# Out:
#               YEAR
# count    52.000000
# mean   2017.500000
# std       1.128942
# min    2016.000000
# 25%    2016.750000
# 50%    2017.500000
# 75%    2018.250000
# max    2019.000000

# %%
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in array_func(values)
#    1586             try:
# -> 1587                 result = self.grouper._cython_operation(
#    1588                     "aggregate", values, how, axis=data.ndim - 1, min_count=min_count
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     938         ngroups = self.ngroups
# --> 939         return cy_op.cython_operation(
#     940             values=values,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     625
# --> 626         return self._cython_op_ndim_compat(
#     627             values,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     450                 result_mask = result_mask[None, :]
# --> 451             res = self._call_cython_op(
#     452                 values2d,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     515         out_shape = self._get_output_shape(ngroups, values)
# --> 516         func, values = self.get_cython_func_and_vals(values, is_numeric)
#     517         out_dtype = self.get_out_dtype(values.dtype)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in get_cython_func_and_vals(self, values, is_numeric)
#     198
# --> 199         func = self._get_cython_function(kind, how, values.dtype, is_numeric)
#     200
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _get_cython_function(cls, kind, how, dtype, is_numeric)
#     163                 # raise NotImplementedError here rather than TypeError later
# --> 164                 raise NotImplementedError(
#     165                     f"function is not implemented for this dtype: "
#
# NotImplementedError: function is not implemented for this dtype: [how->mean,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1621         try:
# -> 1622             x = float(x)
#    1623         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '10.58.79.38.5'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1625             try:
# -> 1626                 x = complex(x)
#    1627             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15504\1850836583.py in <module>
#       1 # Group by demographic and calculate mean percentage
# ----> 2 mean_percentage_by_demographic = data.groupby('DEMOGRAPHIC')['PERCENT'].mean()
#       3 print(mean_percentage_by_demographic)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, numeric_only, engine, engine_kwargs)
#    1963             return self._numba_agg_general(sliding_mean, engine_kwargs, "groupby_mean")
#    1964         else:
# -> 1965             result = self._cython_agg_general(
#    1966                 "mean",
#    1967                 alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1599         # TypeError -> we may have an exception in trying to aggregate
#    1600         #  continue and exclude the block
# -> 1601         new_mgr = data.grouped_reduce(array_func, ignore_failures=True)
#    1602
#    1603         if not is_ser and len(new_mgr) < len(data):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\base.py in grouped_reduce(self, func, ignore_failures)
#     197
#     198         arr = self.array
# --> 199         res = func(arr)
#     200         index = default_index(len(res))
#     201
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in array_func(values)
#    1593                 # try to python agg
#    1594                 # TODO: shouldn't min_count matter?
# -> 1595                 result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1596
#    1597             return result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _agg_py_fallback(self, values, ndim, alt)
#    1547         #  should always be preserved by the implemented aggregations
#    1548         # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1549         res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1550
#    1551         if isinstance(values, Categorical):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func, preserve_dtype)
#     979
#     980         else:
# --> 981             result = self._aggregate_series_pure_python(obj, func)
#     982
#     983         npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_pure_python(self, obj, func)
#    1003         for i, group in enumerate(splitter):
#    1004             group = group.__finalize__(obj, method="groupby")
# -> 1005             res = func(group)
#    1006             res = libreduction.extract_result(res)
#    1007
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#    1965             result = self._cython_agg_general(
#    1966                 "mean",
# -> 1967                 alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    1968                 numeric_only=numeric_only_bool,
#    1969             )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11122             **kwargs,
#   11123         ):
# > 11124             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11125
#   11126         setattr(cls, "mean", mean)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10692         **kwargs,
#   10693     ) -> Series | float:
# > 10694         return self._stat_function(
#   10695             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10696         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10644                 name, axis=axis, level=level, skipna=skipna, numeric_only=numeric_only
#   10645             )
# > 10646         return self._reduce(
#   10647             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10648         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4469                 )
#    4470             with np.errstate(all="ignore"):
# -> 4471                 return op(delegate, skipna=skipna, **kwds)
#    4472
#    4473     def _reindex_indexer(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      91             try:
#      92                 with np.errstate(invalid="ignore"):
# ---> 93                     return f(*args, **kwargs)
#      94             except ValueError as e:
#      95                 # we want to transform an object array
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     153                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     154             else:
# --> 155                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     156
#     157             return result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     408             mask = isna(values)
#     409
# --> 410         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     411
#     412         if datetimelike:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     696
#     697     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 698     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     699
#     700     if axis is not None and getattr(the_sum, "ndim", False):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\nanops.py in _ensure_numeric(x)
#    1627             except ValueError as err:
#    1628                 # e.g. "foo"
# -> 1629                 raise TypeError(f"Could not convert {x} to numeric") from err
#    1630     return x
#    1631
#
# TypeError: Could not convert 10.58.79.38.5 to numeric

# %%
data.dtypes
# Out:
# YEAR            int64
# DEMOGRAPHIC    object
# PERCENT        object
# SE             object
# LOWER95        object
# UPPER95        object
# dtype: object

# %%
# Convert 'PERCENT', 'SE', 'LOWER95', and 'UPPER95' columns to numeric
data['PERCENT'] = pd.to_numeric(data['PERCENT'], errors='coerce')
data['SE'] = pd.to_numeric(data['SE'], errors='coerce')
data['LOWER95'] = pd.to_numeric(data['LOWER95'], errors='coerce')
data['UPPER95'] = pd.to_numeric(data['UPPER95'], errors='coerce')

# Display the data types after conversion
print("Updated Data Types:")
print(data.dtypes)
# Out:
# Updated Data Types:
# YEAR             int64
# DEMOGRAPHIC     object
# PERCENT        float64
# SE             float64
# LOWER95        float64
# UPPER95        float64
# dtype: object

# %%
# Group by demographic and calculate mean percentage
mean_percentage_by_demographic = data.groupby('DEMOGRAPHIC')['PERCENT'].mean()
print(mean_percentage_by_demographic)
# Out:
# DEMOGRAPHIC
# Female                                  9.250
# Hispanic                               13.825
# LGBTQ                                  22.025
# Low Income                             19.000
# Male                                   20.100
# Non-Hispanic African American/Black    14.600
# Non-Hispanic American Indian           28.150
# Non-Hispanic Asian                     10.800
# Non-Hispanic Asian/Pacific Islander    11.325
# Non-Hispanic Pacific Islander             NaN
# Non-Hispanic White                     15.275
# Rural Communities                      19.500
# Total                                  14.575
# Name: PERCENT, dtype: float64

# %%
# Calculate overall smoking prevalence for each year
overall_prevalence = data.groupby('YEAR')['PERCENT'].mean()
print("\nOverall smoking prevalence by year:")
print(overall_prevalence)
# Out:
# Overall smoking prevalence by year:
# YEAR
# 2016    19.372727
# 2017    16.675000
# 2018    15.216667
# 2019    14.866667
# Name: PERCENT, dtype: float64

# %%
# Calculate smoking prevalence by demographic group
prevalence_by_demographic = data.groupby('DEMOGRAPHIC')['PERCENT'].mean()
print("\nSmoking prevalence by demographic group:")
print(prevalence_by_demographic)
# Out:
# Smoking prevalence by demographic group:
# DEMOGRAPHIC
# Female                                  9.250
# Hispanic                               13.825
# LGBTQ                                  22.025
# Low Income                             19.000
# Male                                   20.100
# Non-Hispanic African American/Black    14.600
# Non-Hispanic American Indian           28.150
# Non-Hispanic Asian                     10.800
# Non-Hispanic Asian/Pacific Islander    11.325
# Non-Hispanic Pacific Islander             NaN
# Non-Hispanic White                     15.275
# Rural Communities                      19.500
# Total                                  14.575
# Name: PERCENT, dtype: float64

# %%
# Plot smoking prevalence trends over time
import matplotlib.pyplot as plt

# %%
 plt.plot(group_data['YEAR'], group_data['PERCENT'], label=demographic)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15504\2395684850.py in <module>
# ----> 1 plt.plot(group_data['YEAR'], group_data['PERCENT'], label=demographic)
#
# NameError: name 'group_data' is not defined

# %%
plt.figure(figsize=(10, 6))
for demographic, group_data in data.groupby('DEMOGRAPHIC'):
    plt.plot(group_data['YEAR'], group_data['PERCENT'], label=demographic)
    plt.xlabel('Year')
plt.ylabel('Smoking Prevalence (%)')
plt.title('Smoking Prevalence Trends by Demographic Group')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
for demographic, group_data in data.groupby('DEMOGRAPHIC'):
    plt.bar(group_data['YEAR'], group_data['PERCENT'], label=demographic)
    plt.xlabel('Year')
plt.ylabel('Smoking Prevalence (%)')
plt.title('Smoking Prevalence Trends by Demographic Group')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
for demographic, group_data in data.groupby('DEMOGRAPHIC'):
    plt.scatter(group_data['YEAR'], group_data['PERCENT'], label=demographic)
    plt.xlabel('Year')
plt.ylabel('Smoking Prevalence (%)')
plt.title('Smoking Prevalence Trends by Demographic Group')
plt.legend()
plt.grid(True)
plt.show()
